# %%
# Database Dependencies
import pymongo
import gridfs
import pandas as pd
import io
import numpy as np
from PIL import Image, ImageOps
import subprocess
from config import DB_NAME, FEAT_3_COLLECTION_NAME, FEAT_30_COLLECTION_NAME
import json 
from collections import defaultdict
from pathlib import Path
import os

# Machine Learning Dependencies
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
import sklearn.metrics
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# Plotting Dependencies
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# # Database Connection and Loading Data

# %%
# Establish mongo instance and get Music database
client = pymongo.MongoClient('localhost')
db = client[DB_NAME]

# %%
# Select 'feat_3' collection, and read in as pandas DataFrame
collection = db[FEAT_3_COLLECTION_NAME].find()
features_3_df = pd.DataFrame(list(collection))

# Drop mongo generated hash-code id column
features_3_df = features_3_df.drop(columns = ["_id"])
features_3_df
# Out:
#                filename  length  chroma_stft_mean  chroma_stft_var  rms_mean  \
# 0     blues.00000.0.wav   66149          0.335406         0.091048  0.130405
# 1     blues.00000.1.wav   66149          0.343065         0.086147  0.112699
# 2     blues.00000.2.wav   66149          0.346815         0.092243  0.132003
# 3     blues.00000.3.wav   66149          0.363639         0.086856  0.132565
# 4     blues.00000.4.wav   66149          0.335579         0.088129  0.143289
# ...                 ...     ...               ...              ...       ...
# 9985   rock.00099.5.wav   66149          0.349126         0.080515  0.050019
# 9986   rock.00099.6.wav   66149          0.372564         0.082626  0.057897
# 9987   rock.00099.7.wav   66149          0.347481         0.089019  0.052403
# 9988   rock.00099.8.wav   66149          0.387527         0.084815  0.066430
# 9989   rock.00099.9.wav   66149          0.369293         0.086759  0.050524
#
# ...

# %%
# Select 'feat_30' collection, and read in as pandas DataFrame
collection = db[FEAT_30_COLLECTION_NAME].find()
features_30_df = pd.DataFrame(list(collection))

# Drop mongo generated hash-code id column
features_30_df = features_30_df.drop(columns = ["_id"])
features_30_df
# Out:
#             filename  length  chroma_stft_mean  chroma_stft_var  rms_mean  \
# 0    blues.00001.wav  661794          0.340914         0.094980  0.095948
# 1    blues.00000.wav  661794          0.350088         0.088757  0.130228
# 2    blues.00002.wav  661794          0.363637         0.085275  0.175570
# 3    blues.00003.wav  661794          0.404785         0.093999  0.141093
# 4    blues.00004.wav  661794          0.308526         0.087841  0.091529
# ..               ...     ...               ...              ...       ...
# 995   rock.00095.wav  661794          0.352063         0.080487  0.079486
# 996   rock.00096.wav  661794          0.398687         0.075086  0.076458
# 997   rock.00097.wav  661794          0.432142         0.075268  0.081651
# 998   rock.00098.wav  661794          0.362485         0.091506  0.083860
# 999   rock.00099.wav  661794          0.358401         0.085884  0.054454
#
#       rms_var  spectral_centroid_mean  spectral_centroid_var  \
# ...

# %%
# Gets full path of current working directory 
# cwd_bytes = subprocess.check_output("pwd")
# cwd = (cwd_bytes.decode("utf-8").rstrip("\n") + ("/"))

# For Windows users 
cwd = os.getcwd()
print(cwd)
# Out:
# C:\Users\Eric\Desktop\BootCamp\FinalProject\MusicClassification

# %% [markdown]
# # Supervised Machine Learning Model "RandomForestClassifier" to Predict `label` from feature data

# %% [markdown]
# ### Begin `features_3_sec.csv` section

# %%
# Separate Features (X) from the Target (y)
y_3 = features_3_df["label"]
X_3 = features_3_df.drop(columns="label", axis=1)

# %%
# Drop `filename` (identifier/same as `label`) and `length` (same for all songs - 3 sec sample)
# from features X
X_3 = X_3.drop(columns=["filename", "length"], axis=1)
X_3
# Out:
#       chroma_stft_mean  chroma_stft_var  rms_mean   rms_var  \
# 0             0.335406         0.091048  0.130405  0.003521
# 1             0.343065         0.086147  0.112699  0.001450
# 2             0.346815         0.092243  0.132003  0.004620
# 3             0.363639         0.086856  0.132565  0.002448
# 4             0.335579         0.088129  0.143289  0.001701
# ...                ...              ...       ...       ...
# 9985          0.349126         0.080515  0.050019  0.000097
# 9986          0.372564         0.082626  0.057897  0.000088
# 9987          0.347481         0.089019  0.052403  0.000701
# 9988          0.387527         0.084815  0.066430  0.000320
# 9989          0.369293         0.086759  0.050524  0.000067
#
#       spectral_centroid_mean  spectral_centroid_var  spectral_bandwidth_mean  \
# 0                1773.065032          167541.630869              1972.744388
# 1                1816.693777           90525.690866              2010.051501
# ...

# %%
# Encode class labels in target y
genre_nums = {}
cnt = 0
for genre in y_3.unique():
    genre_nums[genre] = cnt
    cnt += 1

y_3 = y_3.apply(lambda x: genre_nums[x])
genre_nums
# Out:
# {'blues': 0,
#  'classical': 1,
#  'country': 2,
#  'disco': 3,
#  'hiphop': 4,
#  'jazz': 5,
#  'metal': 6,
#  'pop': 7,
#  'reggae': 8,
#  'rock': 9}

# %%
# Split into training and testing sets
X_3_train, X_3_test, y_3_train, y_3_test = train_test_split(X_3, y_3, random_state=0)

# %%
# Instantiate the model
rf_3_model = RandomForestClassifier(n_estimators=1400, min_samples_split=2, min_samples_leaf=1,
                                    max_features="auto", max_depth=40, bootstrap=False)  # CHANGEABLE for bar plot comparisons

# Fit the model
rf_3_model = rf_3_model.fit(X_3_train, y_3_train)

# Make predicitions using the testing data
rf_3_pred = rf_3_model.predict(X_3_test)
results = pd.DataFrame({
    "Prediction": rf_3_pred,
    "Actual": y_3_test
}).reset_index(drop=True)
results
# Out:
#       Prediction  Actual
# 0              8       8
# 1              8       8
# 2              9       9
# 3              0       0
# 4              6       9
# ...          ...     ...
# 2493           1       1
# 2494           3       3
# 2495           0       2
# 2496           0       0
# 2497           3       3
#
# [2498 rows x 2 columns]

# %%
# Generate confusion matrix as colored heatmap
cm_3 = sklearn.metrics.confusion_matrix(y_3_test, rf_3_pred)

sortedlabels = genre_nums.keys()
cm_3_df = pd.DataFrame(cm_3, index=sortedlabels, columns=sortedlabels)

sns.set(font_scale=1.3)
sns.heatmap(cm_3_df, linewidths=0.5, cmap=sns.light_palette((1, 0.2, 0.6), n_colors=10000), annot=True)
sns.set(rc={"figure.figsize": (15.0, 13.0)})

plt.title("Confusiuon Matrix Heatmap for 3 Second Sample Features")
plt.xlabel("Predicted")
plt.ylabel("True")
# Out:
# Text(26.499999999999996, 0.5, 'True')

# %%
# Calculate Accuracy Score
acc_score_3 = sklearn.metrics.accuracy_score(y_3_test, rf_3_pred)
acc_score_3
# Out:
# 0.9011208967173739

# %%
# Print classification report
print(sklearn.metrics.classification_report(y_3_test, rf_3_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.93      0.90       236
#            1       0.93      0.97      0.95       247
#            2       0.84      0.87      0.86       263
#            3       0.85      0.91      0.88       229
#            4       0.94      0.89      0.91       262
#            5       0.91      0.91      0.91       251
#            6       0.92      0.93      0.92       259
#            7       0.93      0.88      0.90       242
#            8       0.92      0.92      0.92       265
#            9       0.91      0.80      0.85       244
#
#     accuracy                           0.90      2498
#    macro avg       0.90      0.90      0.90      2498
# weighted avg       0.90      0.90      0.90      2498

# %%
# Organizes clasification report into DataFrames to more easily read and export
classification_report_3_second = sklearn.metrics.classification_report(y_3_test, rf_3_pred, output_dict=True)
genre_metrics_3 = {}
for i in range(10):
    genre_metrics_3[str(i)] = classification_report_3_second[str(i)]
total_accuracy_3 = classification_report_3_second["accuracy"]
common_metrics_3 = {"macro avg": classification_report_3_second["macro avg"],
                  "weighted avg": classification_report_3_second["weighted avg"]}
genre_metrics_3_df = pd.DataFrame.from_dict(genre_metrics_3)
genre_metrics_3_df.columns = list(genre_nums.keys())
common_metrics_3_df = pd.DataFrame.from_dict(common_metrics_3)

# %%
print("Total Accuracy:", total_accuracy_3)
# Out:
# Total Accuracy: 0.9011208967173739

# %%
# Most important features
# List in descending order by feature importance
importances = rf_3_model.feature_importances_
sorted(zip(importances, X_3), reverse=True)[:5]
# Out:
# [(0.05422769922271109, 'perceptr_var'),
#  (0.037311512963851635, 'rms_var'),
#  (0.03624247370078294, 'chroma_stft_mean'),
#  (0.03372315629777902, 'rms_mean'),
#  (0.032592746053540365, 'mfcc4_mean')]

# %% [markdown]
# ### End `features_3_sec.csv` section

# %% [markdown]
# ### Begin `features_30_sec.csv` section

# %%
# Separate Features (X) from the Target (y)
y_30 = features_30_df["label"]
X_30 = features_30_df.drop(columns="label", axis=1)

# %%
# Drop `filename` (identifier/same as `label`) and `length` (same for all songs - 3 sec sample)
# from features X
X_30 = X_30.drop(columns=["filename", "length"], axis=1)
X_30
# Out:
#      chroma_stft_mean  chroma_stft_var  rms_mean   rms_var  \
# 0            0.340914         0.094980  0.095948  0.002373
# 1            0.350088         0.088757  0.130228  0.002827
# 2            0.363637         0.085275  0.175570  0.002746
# 3            0.404785         0.093999  0.141093  0.006346
# 4            0.308526         0.087841  0.091529  0.002303
# ..                ...              ...       ...       ...
# 995          0.352063         0.080487  0.079486  0.000345
# 996          0.398687         0.075086  0.076458  0.000588
# 997          0.432142         0.075268  0.081651  0.000322
# 998          0.362485         0.091506  0.083860  0.001211
# 999          0.358401         0.085884  0.054454  0.000336
#
#      spectral_centroid_mean  spectral_centroid_var  spectral_bandwidth_mean  \
# 0               1530.176679          375850.073649              2039.036516
# 1               1784.165850          129774.064525              2002.449060
# ...

# %%
# Encode class labels in target y
genre_nums = {}
cnt = 0
for genre in y_30.unique():
    genre_nums[genre] = cnt
    cnt += 1

y_30 = y_30.apply(lambda x: genre_nums[x])
genre_nums
# Out:
# {'blues': 0,
#  'classical': 1,
#  'country': 2,
#  'disco': 3,
#  'hiphop': 4,
#  'jazz': 5,
#  'metal': 6,
#  'pop': 7,
#  'reggae': 8,
#  'rock': 9}

# %%
# Split into training and testing sets
X_30_train, X_30_test, y_30_train, y_30_test = train_test_split(X_30, y_30, random_state=0)

# %%
y_30_test
# Out:
# 993    9
# 859    8
# 298    2
# 553    5
# 672    6
#       ..
# 462    4
# 356    3
# 2      0
# 478    4
# 695    6
# Name: label, Length: 250, dtype: int64

# %%
# Instantiate the model
rf_30_model = RandomForestClassifier(n_estimators=800, min_samples_split=5, min_samples_leaf=1,
                                     max_features="sqrt", max_depth=90, bootstrap=False) # CHANGEABLE for bar plot comparisons

# Fit the model
rf_30_model = rf_30_model.fit(X_30_train, y_30_train)

# Make predicitions using the testing data
rf_30_pred = rf_30_model.predict(X_30_test)
results = pd.DataFrame({
    "Prediction": rf_30_pred,
    "Actual": y_30_test
}).reset_index(drop=True)
results
# Out:
#      Prediction  Actual
# 0             9       9
# 1             8       8
# 2             2       2
# 3             5       5
# 4             6       6
# ..          ...     ...
# 245           4       4
# 246           9       3
# 247           9       0
# 248           4       4
# 249           6       6
#
# [250 rows x 2 columns]

# %%
# Generate confusion matrix as colored heatmap
cm_30 = sklearn.metrics.confusion_matrix(y_30_test, rf_30_pred)

sortedlabels = genre_nums.keys()
cm_30_df = pd.DataFrame(cm_30, index=sortedlabels, columns=sortedlabels)

sns.set(font_scale=1.3)
sns.heatmap(cm_30_df, linewidths=0.5, cmap=sns.light_palette((1, 0.2, 0.6), n_colors=10000), annot=True)
sns.set(rc={"figure.figsize": (15.0, 13.0)})

plt.title("Confusiuon Matrix Heatmap for 3 Second Sample Features")
plt.xlabel("Predicted")
plt.ylabel("True")
# Out:
# Text(107.5, 0.5, 'True')

# %%
# Calculate Accuracy Score
acc_score_30 = sklearn.metrics.accuracy_score(y_30_test, rf_30_pred)
acc_score_30
# Out:
# 0.66

# %%
# Print classification report
print(sklearn.metrics.classification_report(y_30_test, rf_30_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.64      0.76      0.70        21
#            1       0.81      0.81      0.81        16
#            2       0.74      0.57      0.64        30
#            3       0.50      0.46      0.48        26
#            4       0.57      0.61      0.59        28
#            5       0.72      0.81      0.76        26
#            6       0.86      0.89      0.87        27
#            7       0.91      0.77      0.83        26
#            8       0.42      0.50      0.45        20
#            9       0.52      0.50      0.51        30
#
#     accuracy                           0.66       250
#    macro avg       0.67      0.67      0.66       250
# weighted avg       0.67      0.66      0.66       250

# %%
# Organizes clasification report into DataFrames to more easily read and export
classification_report_30_second = sklearn.metrics.classification_report(y_30_test, rf_30_pred, output_dict=True)
genre_metrics_30 = {}
for i in range(10):
    genre_metrics_30[str(i)] = classification_report_30_second[str(i)]
total_accuracy_30 = classification_report_30_second["accuracy"]
common_metrics_30 = {"macro avg": classification_report_30_second["macro avg"],
                  "weighted avg": classification_report_30_second["weighted avg"]}
genre_metrics_30_df = pd.DataFrame.from_dict(genre_metrics_30)
genre_metrics_30_df.columns = list(genre_nums.keys())
common_metrics_30_df = pd.DataFrame.from_dict(common_metrics_30)

# %%
print("Total Accuracy:", total_accuracy_30)
# Out:
# Total Accuracy: 0.66

# %%
# Most important features
# List in descending order by feature importance
importances = rf_30_model.feature_importances_
sorted(zip(importances, X_30), reverse=True)[:5]
# Out:
# [(0.052482563631400095, 'perceptr_var'),
#  (0.05003634925421031, 'chroma_stft_mean'),
#  (0.035516455873089894, 'rms_mean'),
#  (0.033834094421557895, 'chroma_stft_var'),
#  (0.03353747108170927, 'rms_var')]

# %%
# Construct path to save location. Path() converts path string based on os 
save_path_3_Genre_Metrics  = Path(cwd + "/Post_Analysis_Data/Genre_metrics_3_Sec.json")
save_path_3_Common_Metrics = Path(cwd + "/Post_Analysis_Data/common_metrics_3_Sec.json")

save_path_30_Genre_Metrics = Path(cwd + "/Post_Analysis_Data/Genre_metrics_30_Sec.json")
save_path_30_Common_Metrics= Path(cwd + "/Post_Analysis_Data/common_metrics_30_Sec.json")

# %%
# Saves all result dataframes to json files
result = genre_metrics_3_df.to_json(orient="index")
parsed = json.loads(result) 
pretty_json = json.dumps(parsed, indent=4)
text_file = open((save_path_3_Genre_Metrics), "wt")
n = text_file.write(pretty_json)
text_file.close()

result = common_metrics_3_df.to_json(orient="index")
parsed = json.loads(result) 
pretty_json = json.dumps(parsed, indent=4)
text_file = open((save_path_3_Common_Metrics), "wt")
n = text_file.write(pretty_json)
text_file.close()


result = genre_metrics_30_df.to_json(orient="index")
parsed = json.loads(result) 
pretty_json = json.dumps(parsed, indent=4)
text_file = open((save_path_30_Genre_Metrics), "wt")
n = text_file.write(pretty_json)
text_file.close()

result = common_metrics_30_df.to_json(orient="index")
parsed = json.loads(result) 
pretty_json = json.dumps(parsed, indent=4)
text_file = open((save_path_30_Common_Metrics), "wt")
n = text_file.write(pretty_json)
text_file.close()
